# %%
# Code adapted from Udacity's Google Deep Learning tutorial:
# https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/udacity

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import sklearn
from IPython.display import display, Image
from scipy import ndimage
from six.moves.urllib.request import urlretrieve
import pickle
import tensorflow as tf
import sklearn.model_selection
# %matplotlib inline

# %%
# Download and extract the CIFAR-10 dataset.

pixel_depth = 255.0
url = 'https://www.cs.toronto.edu/~kriz/'
last_percent_reported = None
data_root = '.' # Change me to store data elsewhere
num_labels = 10

def download_progress_hook(count, blockSize, totalSize):
  """A hook to report the progress of a download. This is mostly intended for users with
  slow internet connections. Reports every 5% change in download progress.
  """
  global last_percent_reported
  percent = int(count * blockSize * 100 / totalSize)

  if last_percent_reported != percent:
    if percent % 5 == 0:
      sys.stdout.write("%s%%" % percent)
      sys.stdout.flush()
    else:
      sys.stdout.write(".")
      sys.stdout.flush()
      
    last_percent_reported = percent
        
def maybe_download(filename, expected_bytes, force=False):
  """Download a file if not present, and make sure it's the right size."""
  dest_filename = os.path.join(data_root, filename)
  if force or not os.path.exists(dest_filename):
    print('Attempting to download:', filename) 
    filename, _ = urlretrieve(url + filename, dest_filename, reporthook=download_progress_hook)
    print('\nDownload Complete!')
  statinfo = os.stat(dest_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', dest_filename)
  else:
    raise Exception(
      'Failed to verify ' + dest_filename + '. Can you get to it with a browser?')
  return dest_filename

def maybe_extract(filename, force=False):
  root = os.path.splitext(os.path.splitext(filename)[0])[0]  # remove .tar.gz
  if os.path.isdir(root) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping extraction of %s.' % (root, filename))
  else:
    print('Extracting data for %s. This may take a while. Please wait.' % root)
    tar = tarfile.open(filename)
    sys.stdout.flush()
    tar.extractall(data_root)
    tar.close()
    print("And... we're done!")
  return os.listdir(os.path.join(data_root, 'cifar-10-batches-py'))
    
def unpickle(file):
    print ("Unpickling %s" % file)
    with open(file, 'rb') as fo:
        return pickle.load(fo, encoding='latin1')

data_root = os.path.join(data_root, 'cifar-10-batches-py')
train_filename = maybe_download('cifar-10-python.tar.gz', 170498071)
train_files = maybe_extract(train_filename)

def shuffle_data(data, labels):
    data, _, labels, _ = sklearn.model_selection.train_test_split(
        data, labels, test_size=0.0, random_state=42
    )
    return data, labels

def load_data(train_batches):
    data = []
    labels = []
    for data_batch_i in train_batches:
        d = unpickle(
            os.path.join(data_root, data_batch_i)
        )
        data.append(d['data'])
        labels.append(np.array(d['labels']))
    # Merge training batches on their first dimension
    data = np.concatenate(data)
    labels = np.concatenate(labels)
    data = data.astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    length = len(labels)
    data, labels = shuffle_data(data, labels)
    data = (data - (pixel_depth / 2)) / pixel_depth
    return data.reshape(length, 3, 32, 32), labels

train_dataset, train_labels = load_data(
    ["data_batch_{}".format(i) for i in range(1, 6)]
)

test_dataset, test_labels = load_data(["test_batch"])

print("INFO: each dataset's element are of shape 3*32*32:")
print('"print(test_dataset.shape)" --> "{}"\n'.format(test_dataset.shape))
print("From the Caffe documentation: ")
print("The conventional blob dimensions for batches of image data "
      "are number N x channel K x height H x width W.\n")
# Out:
# Found and verified ./cifar-10-batches-py/cifar-10-python.tar.gz
# Extracting data for ./cifar-10-batches-py/cifar-10-python. This may take a while. Please wait.
# And... we're done!
# Unpickling ./cifar-10-batches-py/data_batch_1
# Unpickling ./cifar-10-batches-py/data_batch_2
# Unpickling ./cifar-10-batches-py/data_batch_3
# Unpickling ./cifar-10-batches-py/data_batch_4
# Unpickling ./cifar-10-batches-py/data_batch_5
# Unpickling ./cifar-10-batches-py/test_batch
# INFO: each dataset's element are of shape 3*32*32:
# "print(test_dataset.shape)" --> "(10000, 3, 32, 32)"
#
# From the Caffe documentation:
# The conventional blob dimensions for batches of image data are number N x channel K x height H x width W.

# %%
# Define the neural network

image_size = 32
num_channels = 3
num_labels = 10
batch_size = 256
patch_size = 5
depth = 64
num_hidden = 128
logs_path = "/tmp/tf-logs"

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

graph = tf.Graph()

with graph.as_default():
  writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())
  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels), name="train_dataset")
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels), name="train_labels")
  tf_test_dataset = tf.constant(test_dataset.transpose(0, 2, 3, 1))
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME', name='layer1-conv')
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', name='layer1-maxpool')
    hidden = tf.nn.relu(conv + layer1_biases, name='layer1-relu')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME', name='layer2-conv')
    conv = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME', name='layer2-maxpool')
    hidden = tf.nn.relu(conv + layer2_biases, name='layer2-relu')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
# Evaluate the model.
# Try playing with the number of iterations and batch size, and network parameters.

num_steps = 6001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_data = batch_data.transpose(0, 2, 3, 1)
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
  tp = test_prediction.eval()
  images = test_dataset.transpose(0, 2, 3, 1)
  print('Test accuracy: %.1f%%' % accuracy(tp, test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.068390
# Minibatch accuracy: 9.4%
# Minibatch loss at step 50: 2.066794
# Minibatch accuracy: 28.9%
# Minibatch loss at step 100: 1.801312
# Minibatch accuracy: 39.1%
# Minibatch loss at step 150: 1.749214
# Minibatch accuracy: 41.0%
# Minibatch loss at step 200: 1.582935
# Minibatch accuracy: 41.0%
# Minibatch loss at step 250: 1.636399
# Minibatch accuracy: 45.3%
# Minibatch loss at step 300: 1.544091
# Minibatch accuracy: 46.1%
# Minibatch loss at step 350: 1.480037
# Minibatch accuracy: 48.4%
# Minibatch loss at step 400: 1.669302
# Minibatch accuracy: 40.6%
# Minibatch loss at step 450: 1.379397
# Minibatch accuracy: 50.4%
# Minibatch loss at step 500: 1.522869
# Minibatch accuracy: 46.1%
# Minibatch loss at step 550: 1.378336
# Minibatch accuracy: 52.0%
# Minibatch loss at step 600: 1.457023
# Minibatch accuracy: 46.9%
# Minibatch loss at step 650: 1.430475
# Minibatch accuracy: 48.4%
# Minibatch loss at step 700: 1.457910
# Minibatch accuracy: 50.0%
# Minibatch loss at step 750: 1.285339
# Minibatch accuracy: 55.9%
# Minibatch loss at step 800: 1.275406
# Minibatch accuracy: 53.9%
# Minibatch loss at step 850: 1.364047
# Minibatch accuracy: 52.0%
# Minibatch loss at step 900: 1.507531
# Minibatch accuracy: 46.5%
# Minibatch loss at step 950: 1.419891
# Minibatch accuracy: 52.3%
# Minibatch loss at step 1000: 1.135775
# Minibatch accuracy: 60.2%
# Minibatch loss at step 1050: 1.229930
# Minibatch accuracy: 54.7%
# Minibatch loss at step 1100: 1.195938
# Minibatch accuracy: 56.2%
# Minibatch loss at step 1150: 1.302032
# Minibatch accuracy: 50.8%
# Minibatch loss at step 1200: 1.257432
# Minibatch accuracy: 57.0%
# Minibatch loss at step 1250: 1.190416
# Minibatch accuracy: 54.7%
# Minibatch loss at step 1300: 1.274070
# Minibatch accuracy: 55.1%
# Minibatch loss at step 1350: 1.104673
# Minibatch accuracy: 58.6%
# Minibatch loss at step 1400: 1.038692
# Minibatch accuracy: 59.8%
# Minibatch loss at step 1450: 1.185400
# Minibatch accuracy: 57.0%
# Minibatch loss at step 1500: 1.225462
# Minibatch accuracy: 59.0%
# Minibatch loss at step 1550: 1.180901
# Minibatch accuracy: 61.3%
# Minibatch loss at step 1600: 1.142309
# Minibatch accuracy: 57.4%
# Minibatch loss at step 1650: 1.083656
# Minibatch accuracy: 60.5%
# Minibatch loss at step 1700: 1.189538
# Minibatch accuracy: 55.5%
# Minibatch loss at step 1750: 1.185751
# Minibatch accuracy: 57.0%
# Minibatch loss at step 1800: 1.041487
# Minibatch accuracy: 59.8%
# Minibatch loss at step 1850: 1.035614
# Minibatch accuracy: 63.3%
# Minibatch loss at step 1900: 1.187941
# Minibatch accuracy: 59.8%
# Minibatch loss at step 1950: 0.951780
# Minibatch accuracy: 66.4%
# Minibatch loss at step 2000: 0.982427
# Minibatch accuracy: 62.9%
# Minibatch loss at step 2050: 0.980622
# Minibatch accuracy: 64.5%
# Minibatch loss at step 2100: 1.117210
# Minibatch accuracy: 61.3%
# Minibatch loss at step 2150: 1.082095
# Minibatch accuracy: 64.1%
# Minibatch loss at step 2200: 1.178195
# Minibatch accuracy: 59.0%
# Minibatch loss at step 2250: 0.996074
# Minibatch accuracy: 66.0%
# Minibatch loss at step 2300: 1.129488
# Minibatch accuracy: 60.5%
# Minibatch loss at step 2350: 1.082089
# Minibatch accuracy: 59.8%
# Minibatch loss at step 2400: 1.108454
# Minibatch accuracy: 59.4%
# Minibatch loss at step 2450: 1.077915
# Minibatch accuracy: 59.0%
# Minibatch loss at step 2500: 0.947072
# Minibatch accuracy: 68.0%
# Minibatch loss at step 2550: 1.030365
# Minibatch accuracy: 64.8%
# Minibatch loss at step 2600: 1.013080
# Minibatch accuracy: 69.1%
# Minibatch loss at step 2650: 0.870382
# Minibatch accuracy: 68.4%
# Minibatch loss at step 2700: 0.919414
# Minibatch accuracy: 66.8%
# Minibatch loss at step 2750: 0.869347
# Minibatch accuracy: 66.0%
# Minibatch loss at step 2800: 0.947254
# Minibatch accuracy: 65.2%
# Minibatch loss at step 2850: 0.941970
# Minibatch accuracy: 67.6%
# Minibatch loss at step 2900: 1.082832
# Minibatch accuracy: 60.5%
# Minibatch loss at step 2950: 0.934721
# Minibatch accuracy: 68.0%
# Minibatch loss at step 3000: 0.963194
# Minibatch accuracy: 66.4%
# Minibatch loss at step 3050: 0.883482
# Minibatch accuracy: 66.8%
# Minibatch loss at step 3100: 0.986058
# Minibatch accuracy: 61.3%
# Minibatch loss at step 3150: 0.806208
# Minibatch accuracy: 73.0%
# Minibatch loss at step 3200: 0.953064
# Minibatch accuracy: 69.9%
# Minibatch loss at step 3250: 0.864820
# Minibatch accuracy: 70.7%
# Minibatch loss at step 3300: 1.130027
# Minibatch accuracy: 60.2%
# Minibatch loss at step 3350: 0.867057
# Minibatch accuracy: 72.7%
# Minibatch loss at step 3400: 0.928738
# Minibatch accuracy: 68.4%
# Minibatch loss at step 3450: 0.805427
# Minibatch accuracy: 75.4%
# Minibatch loss at step 3500: 0.752856
# Minibatch accuracy: 75.0%
# Minibatch loss at step 3550: 0.859031
# Minibatch accuracy: 69.9%
# Minibatch loss at step 3600: 1.025638
# Minibatch accuracy: 67.2%
# Minibatch loss at step 3650: 1.003829
# Minibatch accuracy: 66.4%
# Minibatch loss at step 3700: 0.888737
# Minibatch accuracy: 70.7%
# Minibatch loss at step 3750: 0.901593
# Minibatch accuracy: 67.6%
# Minibatch loss at step 3800: 0.860801
# Minibatch accuracy: 69.9%
# Minibatch loss at step 3850: 0.776492
# Minibatch accuracy: 72.7%
# Minibatch loss at step 3900: 0.811988
# Minibatch accuracy: 75.0%
# Minibatch loss at step 3950: 0.718389
# Minibatch accuracy: 73.8%
# Minibatch loss at step 4000: 0.738822
# Minibatch accuracy: 77.7%
# Minibatch loss at step 4050: 0.826664
# Minibatch accuracy: 70.3%
# Minibatch loss at step 4100: 0.867109
# Minibatch accuracy: 69.9%
# Minibatch loss at step 4150: 0.888512
# Minibatch accuracy: 63.3%
# Minibatch loss at step 4200: 0.717377
# Minibatch accuracy: 76.6%
# Minibatch loss at step 4250: 0.894173
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4300: 0.899036
# Minibatch accuracy: 71.5%
# Minibatch loss at step 4350: 0.773424
# Minibatch accuracy: 70.7%
# Minibatch loss at step 4400: 0.703858
# Minibatch accuracy: 78.5%
# Minibatch loss at step 4450: 0.798025
# Minibatch accuracy: 70.7%
# Minibatch loss at step 4500: 0.811843
# Minibatch accuracy: 73.4%
# Minibatch loss at step 4550: 0.844844
# Minibatch accuracy: 73.0%
# Minibatch loss at step 4600: 0.754943
# Minibatch accuracy: 75.4%
# Minibatch loss at step 4650: 0.727795
# Minibatch accuracy: 75.4%
# Minibatch loss at step 4700: 0.783379
# Minibatch accuracy: 75.8%
# Minibatch loss at step 4750: 0.630427
# Minibatch accuracy: 79.7%
# Minibatch loss at step 4800: 0.753532
# Minibatch accuracy: 70.3%
# Minibatch loss at step 4850: 0.716677
# Minibatch accuracy: 75.8%
# Minibatch loss at step 4900: 0.739372
# Minibatch accuracy: 73.8%
# Minibatch loss at step 4950: 0.782716
# Minibatch accuracy: 76.6%
# Minibatch loss at step 5000: 0.720943
# Minibatch accuracy: 77.0%
# Minibatch loss at step 5050: 0.720755
# Minibatch accuracy: 71.9%
# Minibatch loss at step 5100: 0.734507
# Minibatch accuracy: 73.0%
# Minibatch loss at step 5150: 0.706047
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5200: 0.736529
# Minibatch accuracy: 77.0%
# Minibatch loss at step 5250: 0.633079
# Minibatch accuracy: 78.1%
# Minibatch loss at step 5300: 0.638668
# Minibatch accuracy: 77.3%
# Minibatch loss at step 5350: 0.676308
# Minibatch accuracy: 75.4%
# Minibatch loss at step 5400: 0.673233
# Minibatch accuracy: 77.3%
# Minibatch loss at step 5450: 0.612141
# Minibatch accuracy: 77.0%
# Minibatch loss at step 5500: 0.621237
# Minibatch accuracy: 76.2%
# Minibatch loss at step 5550: 0.665736
# Minibatch accuracy: 77.0%
# Minibatch loss at step 5600: 0.736846
# Minibatch accuracy: 74.6%
# Minibatch loss at step 5650: 0.882071
# Minibatch accuracy: 68.0%
# Minibatch loss at step 5700: 0.731925
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5750: 0.610372
# Minibatch accuracy: 81.2%
# Minibatch loss at step 5800: 0.679144
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5850: 0.587606
# Minibatch accuracy: 80.9%
# Minibatch loss at step 5900: 0.700710
# Minibatch accuracy: 73.8%
# Minibatch loss at step 5950: 0.655769
# Minibatch accuracy: 75.4%
# Minibatch loss at step 6000: 0.620055
# Minibatch accuracy: 77.0%
# Minibatch loss at step 6050: 0.583283
# Minibatch accuracy: 78.5%
# Minibatch loss at step 6100: 0.701617
# Minibatch accuracy: 76.2%
# Minibatch loss at step 6150: 0.529186
# Minibatch accuracy: 83.2%
# Minibatch loss at step 6200: 0.557389
# Minibatch accuracy: 81.2%
# Minibatch loss at step 6250: 0.640766
# Minibatch accuracy: 77.0%
# Minibatch loss at step 6300: 0.651941
# Minibatch accuracy: 77.3%
# Minibatch loss at step 6350: 0.550711
# Minibatch accuracy: 80.5%
# Minibatch loss at step 6400: 0.666934
# Minibatch accuracy: 79.3%
# Minibatch loss at step 6450: 0.618095
# Minibatch accuracy: 79.3%
# Minibatch loss at step 6500: 0.612332
# Minibatch accuracy: 78.1%
# Minibatch loss at step 6550: 0.522456
# Minibatch accuracy: 81.6%
# Minibatch loss at step 6600: 0.635242
# Minibatch accuracy: 79.7%
# Minibatch loss at step 6650: 0.580514
# Minibatch accuracy: 78.5%
# Minibatch loss at step 6700: 0.575436
# Minibatch accuracy: 80.5%
# Minibatch loss at step 6750: 0.507084
# Minibatch accuracy: 81.2%
# Minibatch loss at step 6800: 0.593919
# Minibatch accuracy: 77.0%
# Minibatch loss at step 6850: 0.749436
# Minibatch accuracy: 72.3%
# Minibatch loss at step 6900: 0.625334
# Minibatch accuracy: 78.9%
# Minibatch loss at step 6950: 0.491748
# Minibatch accuracy: 81.6%
# Minibatch loss at step 7000: 0.565752
# Minibatch accuracy: 81.6%
# Minibatch loss at step 7050: 0.659079
# Minibatch accuracy: 76.2%
# Minibatch loss at step 7100: 0.481882
# Minibatch accuracy: 84.0%
# Minibatch loss at step 7150: 0.588626
# Minibatch accuracy: 78.9%
# Minibatch loss at step 7200: 0.583338
# Minibatch accuracy: 79.7%
# Minibatch loss at step 7250: 0.495202
# Minibatch accuracy: 83.2%
# Minibatch loss at step 7300: 0.578877
# Minibatch accuracy: 81.6%
# Minibatch loss at step 7350: 0.512471
# Minibatch accuracy: 82.8%
# Minibatch loss at step 7400: 0.546299
# Minibatch accuracy: 79.3%
# Minibatch loss at step 7450: 0.583324
# Minibatch accuracy: 78.5%
# Minibatch loss at step 7500: 0.553392
# Minibatch accuracy: 82.4%
# Minibatch loss at step 7550: 0.589730
# Minibatch accuracy: 80.5%
# Minibatch loss at step 7600: 0.551237
# Minibatch accuracy: 80.5%
# Minibatch loss at step 7650: 0.455161
# Minibatch accuracy: 81.6%
# Minibatch loss at step 7700: 0.549205
# Minibatch accuracy: 83.2%
# Minibatch loss at step 7750: 0.542408
# Minibatch accuracy: 78.9%
# Minibatch loss at step 7800: 0.531532
# Minibatch accuracy: 82.8%
# Minibatch loss at step 7850: 0.484380
# Minibatch accuracy: 82.4%
# Minibatch loss at step 7900: 0.563705
# Minibatch accuracy: 82.0%
# Minibatch loss at step 7950: 0.491094
# Minibatch accuracy: 82.4%
# Minibatch loss at step 8000: 0.438198
# Minibatch accuracy: 82.8%
# Minibatch loss at step 8050: 0.474920
# Minibatch accuracy: 82.4%
# Minibatch loss at step 8100: 0.442211
# Minibatch accuracy: 85.5%
# Minibatch loss at step 8150: 0.431374
# Minibatch accuracy: 84.4%
# Minibatch loss at step 8200: 0.524393
# Minibatch accuracy: 82.8%
# Minibatch loss at step 8250: 0.497185
# Minibatch accuracy: 82.8%
# Minibatch loss at step 8300: 0.546358
# Minibatch accuracy: 81.6%
# Minibatch loss at step 8350: 0.418040
# Minibatch accuracy: 84.0%
# Minibatch loss at step 8400: 0.468349
# Minibatch accuracy: 83.6%
# Minibatch loss at step 8450: 0.467893
# Minibatch accuracy: 83.6%
# Minibatch loss at step 8500: 0.475962
# Minibatch accuracy: 84.0%
# Minibatch loss at step 8550: 0.614951
# Minibatch accuracy: 82.0%
# Minibatch loss at step 8600: 0.473034
# Minibatch accuracy: 84.4%
# Minibatch loss at step 8650: 0.564774
# Minibatch accuracy: 82.4%
# Minibatch loss at step 8700: 0.488962
# Minibatch accuracy: 82.0%
# Minibatch loss at step 8750: 0.390954
# Minibatch accuracy: 87.5%
# Minibatch loss at step 8800: 0.454960
# Minibatch accuracy: 86.7%
# Minibatch loss at step 8850: 0.430273
# Minibatch accuracy: 85.5%
# Minibatch loss at step 8900: 0.441507
# Minibatch accuracy: 86.7%
# Minibatch loss at step 8950: 0.444198
# Minibatch accuracy: 84.0%
# Minibatch loss at step 9000: 0.419729
# Minibatch accuracy: 86.3%
# Minibatch loss at step 9050: 0.446835
# Minibatch accuracy: 85.5%
# Minibatch loss at step 9100: 0.402905
# Minibatch accuracy: 87.1%
# Minibatch loss at step 9150: 0.405675
# Minibatch accuracy: 86.3%
# Minibatch loss at step 9200: 0.434875
# Minibatch accuracy: 86.3%
# Minibatch loss at step 9250: 0.427166
# Minibatch accuracy: 87.1%
# Minibatch loss at step 9300: 0.371493
# Minibatch accuracy: 86.3%
# Minibatch loss at step 9350: 0.368965
# Minibatch accuracy: 85.9%
# Minibatch loss at step 9400: 0.420468
# Minibatch accuracy: 87.1%
# Minibatch loss at step 9450: 0.495298
# Minibatch accuracy: 83.2%
# Minibatch loss at step 9500: 0.361403
# Minibatch accuracy: 87.1%
# Minibatch loss at step 9550: 0.313548
# Minibatch accuracy: 91.8%
# Minibatch loss at step 9600: 0.342074
# Minibatch accuracy: 90.6%
# Minibatch loss at step 9650: 0.399699
# Minibatch accuracy: 86.3%
# Minibatch loss at step 9700: 0.410220
# Minibatch accuracy: 85.5%
# Minibatch loss at step 9750: 0.458437
# Minibatch accuracy: 83.2%
# Minibatch loss at step 9800: 0.392904
# Minibatch accuracy: 84.8%
# Minibatch loss at step 9850: 0.347660
# Minibatch accuracy: 89.1%
# Minibatch loss at step 9900: 0.344661
# Minibatch accuracy: 88.7%
# Minibatch loss at step 9950: 0.346289
# Minibatch accuracy: 85.9%
# Minibatch loss at step 10000: 0.287938
# Minibatch accuracy: 90.2%
# Test accuracy: 67.2%
